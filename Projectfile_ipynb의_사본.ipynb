# %% [markdown]
# <a href="https://colab.research.google.com/github/do04200611/colab/blob/main/Projectfile_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate \
https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
-O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2023-05-25 01:59:01--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.118.128, 74.125.24.128, 142.250.4.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.118.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M  20.4MB/s    in 4.0s
#
# 2023-05-25 01:59:10 (16.3 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %%
# 기본 경로
base_dir = '/tmp/cats_and_dogs_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# 훈련에 사용되는 고양이/개 이미지 경로
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')
print(train_cats_dir)
print(train_dogs_dir)

# 테스트에 사용되는 고양이/개 이미지 경로
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')
print(validation_cats_dir)
print(validation_dogs_dir)
# Out:
# /tmp/cats_and_dogs_filtered/train/cats
# /tmp/cats_and_dogs_filtered/train/dogs
# /tmp/cats_and_dogs_filtered/validation/cats
# /tmp/cats_and_dogs_filtered/validation/dogs

# %%
train_cat_fnames = os.listdir( train_cats_dir )
train_dog_fnames = os.listdir( train_dogs_dir )

print(train_cat_fnames[:5])
print(train_dog_fnames[:5])
# Out:
# ['cat.656.jpg', 'cat.858.jpg', 'cat.471.jpg', 'cat.880.jpg', 'cat.157.jpg']
# ['dog.363.jpg', 'dog.315.jpg', 'dog.963.jpg', 'dog.279.jpg', 'dog.909.jpg']

# %%
['cat.702.jpg', 'cat.589.jpg', 'cat.788.jpg', 'cat.951.jpg', 'cat.265.jpg']
['dog.776.jpg', 'dog.573.jpg', 'dog.575.jpg', 'dog.405.jpg', 'dog.439.jpg']
# Out:
# ['dog.776.jpg', 'dog.573.jpg', 'dog.575.jpg', 'dog.405.jpg', 'dog.439.jpg']

# %%
print('Total training cat images :', len(os.listdir(train_cats_dir)))
print('Total training dog images :', len(os.listdir(train_dogs_dir)))

print('Total validation cat images :', len(os.listdir(validation_cats_dir)))
print('Total validation dog images :', len(os.listdir(validation_dogs_dir)))
# Out:
# Total training cat images : 1000
# Total training dog images : 1000
# Total validation cat images : 500
# Total validation dog images : 500

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows, ncols = 4, 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index+=8

next_cat_pix = [os.path.join(train_cats_dir, fname)
                for fname in train_cat_fnames[ pic_index-8:pic_index]]

next_dog_pix = [os.path.join(train_dogs_dir, fname)
                for fname in train_dog_fnames[ pic_index-8:pic_index]]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import tensorflow as tf


model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(lr=0.001),
            loss='binary_crossentropy',
            metrics = ['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

train_generator = train_datagen.flow_from_directory(train_dir,
                                                  batch_size=20,
                                                  class_mode='binary',
                                                  target_size=(150, 150))
validation_generator =  test_datagen.flow_from_directory(validation_dir,
                                                       batch_size=20,
                                                       class_mode  = 'binary',
                                                       target_size = (150, 150))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=100,
                    epochs=100,
                    validation_steps=50,
                    verbose=2)
# Out:
# Epoch 1/100
# 100/100 - 21s - loss: 0.7285 - accuracy: 0.5345 - val_loss: 0.6814 - val_accuracy: 0.5570 - 21s/epoch - 208ms/step
# Epoch 2/100
# 100/100 - 9s - loss: 0.6454 - accuracy: 0.6530 - val_loss: 0.6068 - val_accuracy: 0.6770 - 9s/epoch - 95ms/step
# Epoch 3/100
# 100/100 - 9s - loss: 0.5765 - accuracy: 0.7020 - val_loss: 0.6162 - val_accuracy: 0.6250 - 9s/epoch - 95ms/step
# Epoch 4/100
# 100/100 - 11s - loss: 0.5094 - accuracy: 0.7505 - val_loss: 0.6846 - val_accuracy: 0.5870 - 11s/epoch - 109ms/step
# Epoch 5/100
# 100/100 - 10s - loss: 0.4466 - accuracy: 0.7880 - val_loss: 0.5177 - val_accuracy: 0.7410 - 10s/epoch - 98ms/step
# Epoch 6/100
# 100/100 - 9s - loss: 0.3912 - accuracy: 0.8230 - val_loss: 0.5917 - val_accuracy: 0.6970 - 9s/epoch - 85ms/step
# Epoch 7/100
# 100/100 - 10s - loss: 0.3097 - accuracy: 0.8655 - val_loss: 0.6067 - val_accuracy: 0.7240 - 10s/epoch - 102ms/step
# Epoch 8/100
# 100/100 - 9s - loss: 0.2336 - accuracy: 0.9000 - val_loss: 0.7409 - val_accuracy: 0.7190 - 9s/epoch - 95ms/step
# Epoch 9/100
# 100/100 - 9s - loss: 0.1878 - accuracy: 0.9240 - val_loss: 0.6988 - val_accuracy: 0.7310 - 9s/epoch - 94ms/step
# Epoch 10/100
# 100/100 - 10s - loss: 0.1127 - accuracy: 0.9590 - val_loss: 0.7213 - val_accuracy: 0.7160 - 10s/epoch - 95ms/step
# Epoch 11/100
# 100/100 - 9s - loss: 0.0651 - accuracy: 0.9785 - val_loss: 1.1045 - val_accuracy: 0.7190 - 9s/epoch - 86ms/step
# Epoch 12/100
# 100/100 - 9s - loss: 0.0816 - accuracy: 0.9810 - val_loss: 0.9831 - val_accuracy: 0.7390 - 9s/epoch - 86ms/step
# Epoch 13/100
# 100/100 - 9s - loss: 0.0298 - accuracy: 0.9925 - val_loss: 1.3648 - val_accuracy: 0.7090 - 9s/epoch - 93ms/step
# Epoch 14/100
# 100/100 - 11s - loss: 0.0371 - accuracy: 0.9885 - val_loss: 1.2991 - val_accuracy: 0.7230 - 11s/epoch - 105ms/step
# Epoch 15/100
# 100/100 - 10s - loss: 0.0562 - accuracy: 0.9835 - val_loss: 1.1279 - val_accuracy: 0.7250 - 10s/epoch - 95ms/step
# Epoch 16/100
# 100/100 - 8s - loss: 0.0466 - accuracy: 0.9920 - val_loss: 1.3017 - val_accuracy: 0.7300 - 8s/epoch - 85ms/step
# Epoch 17/100
# 100/100 - 10s - loss: 0.0387 - accuracy: 0.9910 - val_loss: 1.3756 - val_accuracy: 0.7260 - 10s/epoch - 97ms/step
# Epoch 18/100
# 100/100 - 10s - loss: 0.0150 - accuracy: 0.9965 - val_loss: 1.5566 - val_accuracy: 0.7290 - 10s/epoch - 98ms/step
# Epoch 19/100
# 100/100 - 10s - loss: 0.0304 - accuracy: 0.9895 - val_loss: 1.5578 - val_accuracy: 0.7270 - 10s/epoch - 97ms/step
# Epoch 20/100
# 100/100 - 9s - loss: 0.0085 - accuracy: 0.9970 - val_loss: 2.3728 - val_accuracy: 0.6920 - 9s/epoch - 88ms/step
# Epoch 21/100
# 100/100 - 10s - loss: 0.0308 - accuracy: 0.9910 - val_loss: 1.5352 - val_accuracy: 0.7300 - 10s/epoch - 97ms/step
# Epoch 22/100
# 100/100 - 9s - loss: 0.0173 - accuracy: 0.9945 - val_loss: 2.0261 - val_accuracy: 0.7270 - 9s/epoch - 94ms/step
# Epoch 23/100
# 100/100 - 9s - loss: 0.0328 - accuracy: 0.9950 - val_loss: 2.1918 - val_accuracy: 0.7170 - 9s/epoch - 93ms/step
# Epoch 24/100
# 100/100 - 11s - loss: 0.0185 - accuracy: 0.9925 - val_loss: 2.1599 - val_accuracy: 0.7400 - 11s/epoch - 108ms/step
# Epoch 25/100
# 100/100 - 9s - loss: 0.0067 - accuracy: 0.9980 - val_loss: 2.0112 - val_accuracy: 0.7220 - 9s/epoch - 86ms/step
# Epoch 26/100
# 100/100 - 9s - loss: 0.0325 - accuracy: 0.9935 - val_loss: 2.3193 - val_accuracy: 0.7360 - 9s/epoch - 94ms/step
# Epoch 27/100
# 100/100 - 9s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 2.2381 - val_accuracy: 0.7230 - 9s/epoch - 94ms/step
# Epoch 28/100
# 100/100 - 10s - loss: 0.0155 - accuracy: 0.9955 - val_loss: 2.0717 - val_accuracy: 0.7370 - 10s/epoch - 96ms/step
# Epoch 29/100
# 100/100 - 9s - loss: 0.1097 - accuracy: 0.9915 - val_loss: 2.1390 - val_accuracy: 0.7390 - 9s/epoch - 86ms/step
# Epoch 30/100
# 100/100 - 9s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 2.1064 - val_accuracy: 0.7370 - 9s/epoch - 87ms/step
# Epoch 31/100
# 100/100 - 14s - loss: 0.0228 - accuracy: 0.9950 - val_loss: 1.9788 - val_accuracy: 0.7430 - 14s/epoch - 143ms/step
# Epoch 32/100
# 100/100 - 9s - loss: 0.0367 - accuracy: 0.9910 - val_loss: 2.5307 - val_accuracy: 0.7290 - 9s/epoch - 87ms/step
# Epoch 33/100
# 100/100 - 11s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.3547 - val_accuracy: 0.7290 - 11s/epoch - 107ms/step
# Epoch 34/100
# 100/100 - 10s - loss: 0.1095 - accuracy: 0.9905 - val_loss: 2.2585 - val_accuracy: 0.7340 - 10s/epoch - 96ms/step
# Epoch 35/100
# 100/100 - 10s - loss: 0.0066 - accuracy: 0.9980 - val_loss: 2.2642 - val_accuracy: 0.7240 - 10s/epoch - 96ms/step
# Epoch 36/100
# 100/100 - 9s - loss: 0.0405 - accuracy: 0.9910 - val_loss: 2.2266 - val_accuracy: 0.7340 - 9s/epoch - 88ms/step
# Epoch 37/100
# 100/100 - 10s - loss: 5.4702e-05 - accuracy: 1.0000 - val_loss: 2.4232 - val_accuracy: 0.7300 - 10s/epoch - 97ms/step
# Epoch 38/100
# 100/100 - 11s - loss: 0.0153 - accuracy: 0.9955 - val_loss: 2.3377 - val_accuracy: 0.7200 - 11s/epoch - 112ms/step
# Epoch 39/100
# 100/100 - 11s - loss: 0.0127 - accuracy: 0.9975 - val_loss: 2.6167 - val_accuracy: 0.7220 - 11s/epoch - 109ms/step
# Epoch 40/100
# 100/100 - 9s - loss: 0.0067 - accuracy: 0.9970 - val_loss: 2.5989 - val_accuracy: 0.7400 - 9s/epoch - 86ms/step
# Epoch 41/100
# 100/100 - 9s - loss: 0.0164 - accuracy: 0.9970 - val_loss: 3.0983 - val_accuracy: 0.7280 - 9s/epoch - 87ms/step
# Epoch 42/100
# 100/100 - 10s - loss: 0.0045 - accuracy: 0.9985 - val_loss: 2.9494 - val_accuracy: 0.7280 - 10s/epoch - 95ms/step
# Epoch 43/100
# 100/100 - 10s - loss: 2.8879e-05 - accuracy: 1.0000 - val_loss: 2.8588 - val_accuracy: 0.7320 - 10s/epoch - 100ms/step
# Epoch 44/100
# 100/100 - 10s - loss: 2.8759e-06 - accuracy: 1.0000 - val_loss: 2.9164 - val_accuracy: 0.7390 - 10s/epoch - 96ms/step
# Epoch 45/100
# 100/100 - 12s - loss: 1.1424e-06 - accuracy: 1.0000 - val_loss: 2.9602 - val_accuracy: 0.7390 - 12s/epoch - 116ms/step
# Epoch 46/100
# 100/100 - 9s - loss: 8.6938e-07 - accuracy: 1.0000 - val_loss: 2.9738 - val_accuracy: 0.7350 - 9s/epoch - 86ms/step
# Epoch 47/100
# 100/100 - 9s - loss: 7.1805e-07 - accuracy: 1.0000 - val_loss: 3.0052 - val_accuracy: 0.7340 - 9s/epoch - 87ms/step
# Epoch 48/100
# 100/100 - 10s - loss: 6.1073e-07 - accuracy: 1.0000 - val_loss: 3.0216 - val_accuracy: 0.7350 - 10s/epoch - 96ms/step
# Epoch 49/100
# 100/100 - 10s - loss: 5.4040e-07 - accuracy: 1.0000 - val_loss: 3.0366 - val_accuracy: 0.7350 - 10s/epoch - 98ms/step
# Epoch 50/100
# 100/100 - 12s - loss: 4.8014e-07 - accuracy: 1.0000 - val_loss: 3.0497 - val_accuracy: 0.7360 - 12s/epoch - 119ms/step
# Epoch 51/100
# 100/100 - 9s - loss: 4.3246e-07 - accuracy: 1.0000 - val_loss: 3.0615 - val_accuracy: 0.7370 - 9s/epoch - 91ms/step
# Epoch 52/100
# 100/100 - 11s - loss: 3.9672e-07 - accuracy: 1.0000 - val_loss: 3.0712 - val_accuracy: 0.7370 - 11s/epoch - 110ms/step
# Epoch 53/100
# 100/100 - 10s - loss: 3.6377e-07 - accuracy: 1.0000 - val_loss: 3.0842 - val_accuracy: 0.7370 - 10s/epoch - 97ms/step
# Epoch 54/100
# 100/100 - 10s - loss: 3.4014e-07 - accuracy: 1.0000 - val_loss: 3.0909 - val_accuracy: 0.7380 - 10s/epoch - 97ms/step
# Epoch 55/100
# 100/100 - 10s - loss: 3.1777e-07 - accuracy: 1.0000 - val_loss: 3.0990 - val_accuracy: 0.7370 - 10s/epoch - 96ms/step
# Epoch 56/100
# 100/100 - 11s - loss: 2.9965e-07 - accuracy: 1.0000 - val_loss: 3.1061 - val_accuracy: 0.7370 - 11s/epoch - 111ms/step
# Epoch 57/100
# 100/100 - 9s - loss: 2.8290e-07 - accuracy: 1.0000 - val_loss: 3.1135 - val_accuracy: 0.7370 - 9s/epoch - 86ms/step
# Epoch 58/100
# 100/100 - 10s - loss: 2.6858e-07 - accuracy: 1.0000 - val_loss: 3.1214 - val_accuracy: 0.7380 - 10s/epoch - 96ms/step
# Epoch 59/100
# 100/100 - 10s - loss: 2.5561e-07 - accuracy: 1.0000 - val_loss: 3.1273 - val_accuracy: 0.7380 - 10s/epoch - 95ms/step
# Epoch 60/100
# 100/100 - 10s - loss: 2.4432e-07 - accuracy: 1.0000 - val_loss: 3.1334 - val_accuracy: 0.7380 - 10s/epoch - 95ms/step
# Epoch 61/100
# 100/100 - 9s - loss: 2.3377e-07 - accuracy: 1.0000 - val_loss: 3.1404 - val_accuracy: 0.7390 - 9s/epoch - 86ms/step
# Epoch 62/100
# 100/100 - 10s - loss: 2.2468e-07 - accuracy: 1.0000 - val_loss: 3.1458 - val_accuracy: 0.7390 - 10s/epoch - 97ms/step
# Epoch 63/100
# 100/100 - 10s - loss: 2.1579e-07 - accuracy: 1.0000 - val_loss: 3.1522 - val_accuracy: 0.7390 - 10s/epoch - 97ms/step
# Epoch 64/100
# 100/100 - 10s - loss: 2.0790e-07 - accuracy: 1.0000 - val_loss: 3.1589 - val_accuracy: 0.7390 - 10s/epoch - 96ms/step
# Epoch 65/100
# 100/100 - 9s - loss: 2.0080e-07 - accuracy: 1.0000 - val_loss: 3.1642 - val_accuracy: 0.7400 - 9s/epoch - 85ms/step
# Epoch 66/100
# 100/100 - 9s - loss: 1.9371e-07 - accuracy: 1.0000 - val_loss: 3.1688 - val_accuracy: 0.7400 - 9s/epoch - 85ms/step
# Epoch 67/100
# 100/100 - 9s - loss: 1.8739e-07 - accuracy: 1.0000 - val_loss: 3.1739 - val_accuracy: 0.7400 - 9s/epoch - 92ms/step
# Epoch 68/100
# 100/100 - 9s - loss: 1.8155e-07 - accuracy: 1.0000 - val_loss: 3.1799 - val_accuracy: 0.7410 - 9s/epoch - 91ms/step
# Epoch 69/100
# 100/100 - 10s - loss: 1.7598e-07 - accuracy: 1.0000 - val_loss: 3.1849 - val_accuracy: 0.7410 - 10s/epoch - 98ms/step
# Epoch 70/100
# 100/100 - 9s - loss: 1.7095e-07 - accuracy: 1.0000 - val_loss: 3.1890 - val_accuracy: 0.7400 - 9s/epoch - 91ms/step
# Epoch 71/100
# 100/100 - 9s - loss: 1.6581e-07 - accuracy: 1.0000 - val_loss: 3.1932 - val_accuracy: 0.7410 - 9s/epoch - 89ms/step
# Epoch 72/100
# 100/100 - 8s - loss: 1.6144e-07 - accuracy: 1.0000 - val_loss: 3.1981 - val_accuracy: 0.7410 - 8s/epoch - 84ms/step
# Epoch 73/100
# 100/100 - 9s - loss: 1.5706e-07 - accuracy: 1.0000 - val_loss: 3.2015 - val_accuracy: 0.7410 - 9s/epoch - 90ms/step
# Epoch 74/100
# 100/100 - 9s - loss: 1.5314e-07 - accuracy: 1.0000 - val_loss: 3.2059 - val_accuracy: 0.7400 - 9s/epoch - 91ms/step
# Epoch 75/100
# 100/100 - 9s - loss: 1.4924e-07 - accuracy: 1.0000 - val_loss: 3.2102 - val_accuracy: 0.7390 - 9s/epoch - 90ms/step
# Epoch 76/100
# 100/100 - 11s - loss: 1.4558e-07 - accuracy: 1.0000 - val_loss: 3.2147 - val_accuracy: 0.7390 - 11s/epoch - 107ms/step
# Epoch 77/100
# 100/100 - 9s - loss: 1.4242e-07 - accuracy: 1.0000 - val_loss: 3.2188 - val_accuracy: 0.7390 - 9s/epoch - 87ms/step
# Epoch 78/100
# 100/100 - 9s - loss: 1.3901e-07 - accuracy: 1.0000 - val_loss: 3.2223 - val_accuracy: 0.7390 - 9s/epoch - 89ms/step
# Epoch 79/100
# 100/100 - 9s - loss: 1.3591e-07 - accuracy: 1.0000 - val_loss: 3.2261 - val_accuracy: 0.7390 - 9s/epoch - 91ms/step
# Epoch 80/100
# 100/100 - 9s - loss: 1.3305e-07 - accuracy: 1.0000 - val_loss: 3.2297 - val_accuracy: 0.7390 - 9s/epoch - 90ms/step
# Epoch 81/100
# 100/100 - 9s - loss: 1.3019e-07 - accuracy: 1.0000 - val_loss: 3.2334 - val_accuracy: 0.7390 - 9s/epoch - 91ms/step
# Epoch 82/100
# 100/100 - 11s - loss: 1.2751e-07 - accuracy: 1.0000 - val_loss: 3.2368 - val_accuracy: 0.7390 - 11s/epoch - 108ms/step
# Epoch 83/100
# 100/100 - 8s - loss: 1.2500e-07 - accuracy: 1.0000 - val_loss: 3.2406 - val_accuracy: 0.7390 - 8s/epoch - 84ms/step
# Epoch 84/100
# 100/100 - 9s - loss: 1.2242e-07 - accuracy: 1.0000 - val_loss: 3.2441 - val_accuracy: 0.7390 - 9s/epoch - 86ms/step
# Epoch 85/100

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():

  path='/content/' + fn
  img=image.load_img(path, target_size=(150, 150))

  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])

  classes = model.predict(images, batch_size=10)

  print(classes[0])

  if classes[0]>0:
    print(fn + " is a dog")
  else:
    print(fn + " is a cat")
